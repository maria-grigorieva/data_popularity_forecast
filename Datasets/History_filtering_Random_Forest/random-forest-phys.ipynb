# %%
import pandas as pd
import pprint

import matplotlib
# for interactive plots in Jupyter:
# matplotlib.use('qtagg')

from random_forest_train_test_validate import train_test_validate

# %%
history_lens = [
    pd.Timedelta('365 days'),
    pd.Timedelta('270 days'),
    pd.Timedelta('180 days'),
    pd.Timedelta('90 days'),
]

span_thresholds = [
    pd.Timedelta('90 days'),
    pd.Timedelta('60 days'),
    pd.Timedelta('40 days'),
    pd.Timedelta('20 days'),
]

# history_len = pd.Timedelta('365 days')
# span_threshold = pd.Timedelta('90 days')

accesses_threshold = 30
source_csv = (
    '/home/mshubin/Desktop/datasets-popularity-task-data/' +
    'datasets_popularity_DAOD_PHYS_mc16_13TeV_202308141254.csv'
)
finish_date_train_test = pd.Timestamp('2022-05-28')
finish_date_validate = pd.Timestamp('2022-11-19')
horizon = pd.Timedelta('7 days')
Ntest = 300

# %%
results_list = []

for history_len, span_threshold in zip(history_lens, span_thresholds):
    print(f'\nRUNNING TEST FOR HISTORY LEN = {history_len.days} DAYS\n')
    res = train_test_validate(
        history_len = history_len,
        span_threshold = span_threshold,
        accesses_threshold = accesses_threshold,
        source_csv = source_csv,
        finish_date_train_test = finish_date_train_test,
        finish_date_validate = finish_date_validate,
        horizon = horizon,
        Ntest = Ntest,
    )
    results_list.append((history_len, res))
# Out:
# RUNNING TEST FOR HISTORY LEN = 365 DAYS
#
# merging datasets with different tids
# 100%|██████████████████████████████| 441296/441296 [00:00<00:00, 1279526.37it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|█████████████████████████████████████| 9937/9937 [00:02<00:00, 4860.95it/s]
# after filtering by access number: 484 / 2304
# filtering by history presence
# 100%|█████████████████████████████████████| 2304/2304 [00:01<00:00, 1891.32it/s]
# after filtering: 374 / 1552
# transforming date arrays to timeseries
# 100%|██████████████████████████████████████| 1552/1552 [00:06<00:00, 232.80it/s]
# Accuracy: 0.8966666666666666
# Confusion Matrix
# [[224   8]
#  [ 23  45]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       232
#            1       0.85      0.66      0.74        68
#
#     accuracy                           0.90       300
#    macro avg       0.88      0.81      0.84       300
# weighted avg       0.89      0.90      0.89       300
#
# merging datasets with different tids
# 100%|██████████████████████████████| 441296/441296 [00:00<00:00, 1288713.94it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|███████████████████████████████████| 13088/13088 [00:02<00:00, 5453.70it/s]
# after filtering by access number: 261 / 3075
# filtering by history presence
# 100%|█████████████████████████████████████| 3075/3075 [00:03<00:00, 1000.61it/s]
# after filtering: 258 / 2065
# transforming date arrays to timeseries
# 100%|██████████████████████████████████████| 2065/2065 [00:06<00:00, 296.30it/s]
# Accuracy: 0.8750605326876514
# Confusion Matrix
# [[1807    0]
#  [ 258    0]]
# None
#
# RUNNING TEST FOR HISTORY LEN = 270 DAYS
#
# merging datasets with different tids
# 100%|██████████████████████████████| 441296/441296 [00:00<00:00, 1264856.01it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|█████████████████████████████████████| 9937/9937 [00:02<00:00, 4899.18it/s]
# after filtering by access number: 484 / 2304
# filtering by history presence
# 100%|█████████████████████████████████████| 2304/2304 [00:02<00:00, 1144.91it/s]
# after filtering: 427 / 1626
# transforming date arrays to timeseries
# 100%|██████████████████████████████████████| 1626/1626 [00:04<00:00, 325.58it/s]
# Accuracy: 0.89
# Confusion Matrix
# [[213  11]
#  [ 22  54]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       224
#            1       0.83      0.71      0.77        76
#
#     accuracy                           0.89       300
#    macro avg       0.87      0.83      0.85       300
# weighted avg       0.89      0.89      0.89       300
#
# merging datasets with different tids
# 100%|██████████████████████████████| 441296/441296 [00:00<00:00, 1329419.56it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|███████████████████████████████████| 13088/13088 [00:02<00:00, 5372.82it/s]
# after filtering by access number: 261 / 3075
# filtering by history presence
# 100%|██████████████████████████████████████| 3075/3075 [00:03<00:00, 816.67it/s]
# after filtering: 261 / 2091
# transforming date arrays to timeseries
# 100%|██████████████████████████████████████| 2091/2091 [00:05<00:00, 349.61it/s]
# Accuracy: 0.8751793400286944
# Confusion Matrix
# [[1830    0]
#  [ 261    0]]
# None
#
# RUNNING TEST FOR HISTORY LEN = 180 DAYS
#
# merging datasets with different tids
# 100%|██████████████████████████████| 441296/441296 [00:00<00:00, 1336888.09it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|█████████████████████████████████████| 9937/9937 [00:02<00:00, 4946.03it/s]
# after filtering by access number: 484 / 2304
# filtering by history presence
# 100%|██████████████████████████████████████| 2304/2304 [00:03<00:00, 696.87it/s]
# after filtering: 480 / 2205
# transforming date arrays to timeseries
# 100%|██████████████████████████████████████| 2205/2205 [00:04<00:00, 476.07it/s]
# Accuracy: 0.8966666666666666
# Confusion Matrix
# [[238   0]
#  [ 31  31]]
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       238
#            1       1.00      0.50      0.67        62
#
#     accuracy                           0.90       300
#    macro avg       0.94      0.75      0.80       300
# weighted avg       0.91      0.90      0.88       300
#
# merging datasets with different tids
# 100%|██████████████████████████████| 441296/441296 [00:00<00:00, 1368510.48it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|███████████████████████████████████| 13088/13088 [00:02<00:00, 5422.78it/s]
# after filtering by access number: 261 / 3075
# filtering by history presence
# 100%|██████████████████████████████████████| 3075/3075 [00:03<00:00, 914.87it/s]
# after filtering: 261 / 2611
# transforming date arrays to timeseries
# 100%|██████████████████████████████████████| 2611/2611 [00:05<00:00, 516.27it/s]
# Accuracy: 0.8981233243967829
# Confusion Matrix
# [[2345    5]
#  [ 261    0]]
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      2350
#            1       0.00      0.00      0.00       261
#
#     accuracy                           0.90      2611
#    macro avg       0.45      0.50      0.47      2611
# weighted avg       0.81      0.90      0.85      2611
#
#
# RUNNING TEST FOR HISTORY LEN = 90 DAYS
#
# merging datasets with different tids
# 100%|██████████████████████████████| 441296/441296 [00:00<00:00, 1359645.98it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|█████████████████████████████████████| 9937/9937 [00:01<00:00, 5083.99it/s]
# after filtering by access number: 484 / 2304
# filtering by history presence
# 100%|██████████████████████████████████████| 2304/2304 [00:02<00:00, 797.61it/s]
# after filtering: 481 / 2269
# transforming date arrays to timeseries
# 100%|██████████████████████████████████████| 2269/2269 [00:03<00:00, 591.79it/s]
# Accuracy: 0.8566666666666667
# Confusion Matrix
# [[226   1]
#  [ 42  31]]
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       227
#            1       0.97      0.42      0.59        73
#
#     accuracy                           0.86       300
#    macro avg       0.91      0.71      0.75       300
# weighted avg       0.87      0.86      0.83       300
#
# merging datasets with different tids
# 100%|██████████████████████████████| 441296/441296 [00:00<00:00, 1361757.64it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|███████████████████████████████████| 13088/13088 [00:02<00:00, 5459.96it/s]
# after filtering by access number: 261 / 3075
# filtering by history presence
# 100%|██████████████████████████████████████| 3075/3075 [00:04<00:00, 673.01it/s]
# after filtering: 261 / 2650
# transforming date arrays to timeseries
# 100%|██████████████████████████████████████| 2650/2650 [00:03<00:00, 681.65it/s]
# Accuracy: 0.9015094339622641
# Confusion Matrix
# [[2389    0]
#  [ 261    0]]
# None

# %% [markdown]
# ## Print results

# %%
for hist_len, res in results_list:
    print(hist_len.days, 'days')
    print('   ', 'accuracy (test):', res['test_accuracy'])
    print('   ', 'accuracy (val):', res['val_accuracy'])

print()

for hist_len, res in results_list:
    print()
    print(hist_len.days, 'days')
    print()
    print(res['test_confusion_matrix'])
    print(res['test_classification_report'])
    print(res['val_confusion_matrix'])
    print(res['val_classification_report'])
# Out:
# 365 days
#     accuracy (test): 0.8966666666666666
#     accuracy (val): 0.8750605326876514
# 270 days
#     accuracy (test): 0.89
#     accuracy (val): 0.8751793400286944
# 180 days
#     accuracy (test): 0.8966666666666666
#     accuracy (val): 0.8981233243967829
# 90 days
#     accuracy (test): 0.8566666666666667
#     accuracy (val): 0.9015094339622641
#
#
# 365 days
#
# [[224   8]
#  [ 23  45]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       232
#            1       0.85      0.66      0.74        68
#
#     accuracy                           0.90       300
#    macro avg       0.88      0.81      0.84       300
# weighted avg       0.89      0.90      0.89       300
#
# [[1807    0]
#  [ 258    0]]
# None
#
# 270 days
#
# [[213  11]
#  [ 22  54]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       224
#            1       0.83      0.71      0.77        76
#
#     accuracy                           0.89       300
#    macro avg       0.87      0.83      0.85       300
# weighted avg       0.89      0.89      0.89       300
#
# [[1830    0]
#  [ 261    0]]
# None
#
# 180 days
#
# [[238   0]
#  [ 31  31]]
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       238
#            1       1.00      0.50      0.67        62
#
#     accuracy                           0.90       300
#    macro avg       0.94      0.75      0.80       300
# weighted avg       0.91      0.90      0.88       300
#
# [[2345    5]
#  [ 261    0]]
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      2350
#            1       0.00      0.00      0.00       261
#
#     accuracy                           0.90      2611
#    macro avg       0.45      0.50      0.47      2611
# weighted avg       0.81      0.90      0.85      2611
#
#
# 90 days
#
# [[226   1]
#  [ 42  31]]
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       227
#            1       0.97      0.42      0.59        73
#
#     accuracy                           0.86       300
#    macro avg       0.91      0.71      0.75       300
# weighted avg       0.87      0.86      0.83       300
#
# [[2389    0]
#  [ 261    0]]
# None
