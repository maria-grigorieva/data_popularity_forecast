# %%
import pandas as pd
import pprint

import matplotlib
# for interactive plots in Jupyter:
# matplotlib.use('qtagg')

from random_forest_train_test_validate import train_test_validate

# %%
history_lens = [
    pd.Timedelta('365 days'),
    pd.Timedelta('270 days'),
    pd.Timedelta('180 days'),
    pd.Timedelta('90 days'),
]

span_thresholds = [
    pd.Timedelta('90 days'),
    pd.Timedelta('60 days'),
    pd.Timedelta('40 days'),
    pd.Timedelta('20 days'),
]

# history_len = pd.Timedelta('365 days')
# span_threshold = pd.Timedelta('90 days')

accesses_threshold = 30
source_csv = (
    '/home/mshubin/Desktop/datasets-popularity-task-data/' +
    'datasets_popularity_DAOD_HIGGD_mc16_13TeV_202309211655.csv'
)
finish_date_train_test = pd.Timestamp('2021-10-27')
finish_date_validate = pd.Timestamp('2022-11-24')
horizon = pd.Timedelta('7 days')
Ntest = 1000

# %%
results_list = []

for history_len, span_threshold in zip(history_lens, span_thresholds):
    print(f'\nRUNNING TEST FOR HISTORY LEN = {history_len.days} DAYS\n')
    res = train_test_validate(
        history_len = history_len,
        span_threshold = span_threshold,
        accesses_threshold = accesses_threshold,
        source_csv = source_csv,
        finish_date_train_test = finish_date_train_test,
        finish_date_validate = finish_date_validate,
        horizon = horizon,
        Ntest = Ntest,
    )
    results_list.append((history_len, res))
# Out:
# RUNNING TEST FOR HISTORY LEN = 365 DAYS
#
# merging datasets with different tids
# 100%|████████████████████████████| 1474809/1474809 [00:01<00:00, 1356264.13it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|███████████████████████████████████| 77396/77396 [00:13<00:00, 5663.84it/s]
# after filtering by access number: 1743 / 7452
# filtering by history presence
# 100%|█████████████████████████████████████| 7452/7452 [00:06<00:00, 1184.35it/s]
# after filtering: 1715 / 7328
# transforming date arrays to timeseries
# 100%|██████████████████████████████████████| 7328/7328 [00:10<00:00, 705.15it/s]
# Accuracy: 0.845
# Confusion Matrix
# [[776   1]
#  [154  69]]
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91       777
#            1       0.99      0.31      0.47       223
#
#     accuracy                           0.84      1000
#    macro avg       0.91      0.65      0.69      1000
# weighted avg       0.87      0.84      0.81      1000
#
# merging datasets with different tids
# 100%|████████████████████████████| 1474809/1474809 [00:01<00:00, 1408532.19it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|███████████████████████████████████| 90574/90574 [00:15<00:00, 5767.86it/s]
# after filtering by access number: 1761 / 10055
# filtering by history presence
# 100%|███████████████████████████████████| 10055/10055 [00:08<00:00, 1240.00it/s]
# after filtering: 1754 / 9881
# transforming date arrays to timeseries
# 100%|██████████████████████████████████████| 9881/9881 [00:11<00:00, 824.73it/s]
# Accuracy: 0.8224876024693857
# Confusion Matrix
# [[8127    0]
#  [1754    0]]
# None
#
# RUNNING TEST FOR HISTORY LEN = 270 DAYS
#
# merging datasets with different tids
# 100%|████████████████████████████| 1474809/1474809 [00:01<00:00, 1358992.60it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|███████████████████████████████████| 77396/77396 [00:14<00:00, 5498.25it/s]
# after filtering by access number: 1743 / 7452
# filtering by history presence
# 100%|█████████████████████████████████████| 7452/7452 [00:05<00:00, 1411.48it/s]
# after filtering: 1715 / 7358
# transforming date arrays to timeseries
# 100%|██████████████████████████████████████| 7358/7358 [00:07<00:00, 952.51it/s]
# Accuracy: 0.824
# Confusion Matrix
# [[763   0]
#  [176  61]]
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90       763
#            1       1.00      0.26      0.41       237
#
#     accuracy                           0.82      1000
#    macro avg       0.91      0.63      0.65      1000
# weighted avg       0.86      0.82      0.78      1000
#
# merging datasets with different tids
# 100%|████████████████████████████| 1474809/1474809 [00:01<00:00, 1417994.61it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|███████████████████████████████████| 90574/90574 [00:15<00:00, 5867.26it/s]
# after filtering by access number: 1761 / 10055
# filtering by history presence
# 100%|███████████████████████████████████| 10055/10055 [00:07<00:00, 1432.33it/s]
# after filtering: 1761 / 9985
# transforming date arrays to timeseries
# 100%|█████████████████████████████████████| 9985/9985 [00:09<00:00, 1041.07it/s]
# Accuracy: 0.8236354531797696
# Confusion Matrix
# [[8224    0]
#  [1761    0]]
# None
#
# RUNNING TEST FOR HISTORY LEN = 180 DAYS
#
# merging datasets with different tids
# 100%|████████████████████████████| 1474809/1474809 [00:01<00:00, 1386662.16it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|███████████████████████████████████| 77396/77396 [00:13<00:00, 5636.69it/s]
# after filtering by access number: 1743 / 7452
# filtering by history presence
# 100%|█████████████████████████████████████| 7452/7452 [00:04<00:00, 1577.51it/s]
# after filtering: 1716 / 7387
# transforming date arrays to timeseries
# 100%|█████████████████████████████████████| 7387/7387 [00:06<00:00, 1177.31it/s]
# Accuracy: 0.823
# Confusion Matrix
# [[736   1]
#  [176  87]]
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89       737
#            1       0.99      0.33      0.50       263
#
#     accuracy                           0.82      1000
#    macro avg       0.90      0.66      0.69      1000
# weighted avg       0.85      0.82      0.79      1000
#
# merging datasets with different tids
# 100%|████████████████████████████| 1474809/1474809 [00:01<00:00, 1424605.98it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|███████████████████████████████████| 90574/90574 [00:15<00:00, 5803.53it/s]
# after filtering by access number: 1761 / 10055
# filtering by history presence
# 100%|███████████████████████████████████| 10055/10055 [00:07<00:00, 1425.94it/s]
# after filtering: 1761 / 10012
# transforming date arrays to timeseries
# 100%|███████████████████████████████████| 10012/10012 [00:08<00:00, 1223.74it/s]
# Accuracy: 0.8241110667199361
# Confusion Matrix
# [[8251    0]
#  [1761    0]]
# None
#
# RUNNING TEST FOR HISTORY LEN = 90 DAYS
#
# merging datasets with different tids
# 100%|████████████████████████████| 1474809/1474809 [00:01<00:00, 1395040.36it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|███████████████████████████████████| 77396/77396 [00:13<00:00, 5717.25it/s]
# after filtering by access number: 1743 / 7452
# filtering by history presence
# 100%|█████████████████████████████████████| 7452/7452 [00:04<00:00, 1624.55it/s]
# after filtering: 1726 / 7396
# transforming date arrays to timeseries
# 100%|█████████████████████████████████████| 7396/7396 [00:05<00:00, 1451.72it/s]
# /home/mshubin/soft/app/linux/python3-venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mshubin/soft/app/linux/python3-venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mshubin/soft/app/linux/python3-venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.751
# Confusion Matrix
# [[751   0]
#  [249   0]]
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86       751
#            1       0.00      0.00      0.00       249
#
#     accuracy                           0.75      1000
#    macro avg       0.38      0.50      0.43      1000
# weighted avg       0.56      0.75      0.64      1000
#
# merging datasets with different tids
# 100%|████████████████████████████| 1474809/1474809 [00:01<00:00, 1387897.32it/s]
# filling 'y' and 'n_sub_datasets' columns
# 100%|███████████████████████████████████| 90574/90574 [00:16<00:00, 5659.42it/s]
# after filtering by access number: 1761 / 10055
# filtering by history presence
# 100%|███████████████████████████████████| 10055/10055 [00:07<00:00, 1370.57it/s]
# after filtering: 1761 / 9962
# transforming date arrays to timeseries
# 100%|█████████████████████████████████████| 9962/9962 [00:06<00:00, 1430.61it/s]
# Accuracy: 0.8232282674161815
# Confusion Matrix
# [[8201    0]
#  [1761    0]]
# None

# %% [markdown]
# ## Print results

# %%
for hist_len, res in results_list:
    print(hist_len.days, 'days')
    print('   ', 'accuracy (test):', res['test_accuracy'])
    print('   ', 'accuracy (val):', res['val_accuracy'])

print()

for hist_len, res in results_list:
    print()
    print(hist_len.days, 'days')
    print()
    print(res['test_confusion_matrix'])
    print(res['test_classification_report'])
    print(res['val_confusion_matrix'])
    print(res['val_classification_report'])
# Out:
# 365 days
#     accuracy (test): 0.845
#     accuracy (val): 0.8224876024693857
# 270 days
#     accuracy (test): 0.824
#     accuracy (val): 0.8236354531797696
# 180 days
#     accuracy (test): 0.823
#     accuracy (val): 0.8241110667199361
# 90 days
#     accuracy (test): 0.751
#     accuracy (val): 0.8232282674161815
#
#
# 365 days
#
# [[776   1]
#  [154  69]]
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91       777
#            1       0.99      0.31      0.47       223
#
#     accuracy                           0.84      1000
#    macro avg       0.91      0.65      0.69      1000
# weighted avg       0.87      0.84      0.81      1000
#
# [[8127    0]
#  [1754    0]]
# None
#
# 270 days
#
# [[763   0]
#  [176  61]]
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90       763
#            1       1.00      0.26      0.41       237
#
#     accuracy                           0.82      1000
#    macro avg       0.91      0.63      0.65      1000
# weighted avg       0.86      0.82      0.78      1000
#
# [[8224    0]
#  [1761    0]]
# None
#
# 180 days
#
# [[736   1]
#  [176  87]]
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89       737
#            1       0.99      0.33      0.50       263
#
#     accuracy                           0.82      1000
#    macro avg       0.90      0.66      0.69      1000
# weighted avg       0.85      0.82      0.79      1000
#
# [[8251    0]
#  [1761    0]]
# None
#
# 90 days
#
# [[751   0]
#  [249   0]]
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86       751
#            1       0.00      0.00      0.00       249
#
#     accuracy                           0.75      1000
#    macro avg       0.38      0.50      0.43      1000
# weighted avg       0.56      0.75      0.64      1000
#
# [[8201    0]
#  [1761    0]]
# None
